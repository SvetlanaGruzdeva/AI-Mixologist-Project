# %% [markdown]
# ## TOC:
# * [Converting measures to grams.](#1)
# * [Converting standard measures to ml.](#2)
# * [oz, ml, gal glass, etc.](#3)
# * [Individual cases](#4)
# * [Lemons](#5)
# * [Limes](#6)
# * [Oranges](#7)
# * [Apples](#8)
# * [Pineapples](#9)
# * [Garnishes (remaning after fruit fix)](#10)
# * [Missing measures](#11)

# %%
# import os
import re
# import math
import pandas as pd
import numpy as np
from fractions import Fraction
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sqlalchemy import create_engine
# import pymysql
# import requests
# from bs4 import BeautifulSoup
# from sklearn.linear_model import LinearRegression
# from statsmodels.tsa.ar_model import AR
# from statsmodels.tools.eval_measures import rmse
# from scipy import stats

# %%
pd.set_option('display.max_columns', 100)

# %%
# Split ingredients from description, also include shape of glass, type of ice and way to mix as separate columns.
# Align measurements.
# Add labels: type of alcohol, tastes of other ingredients.

# %%
### Collect cocktails raiting.
# Cross-check with dataset above. Align names. Add missing cocktails?

# %% [markdown]
# **Code below is pretty unstructured because original 'Measures' data is very messy and unstructured. So whatever catches an eye first is corrected first.**

# %% [markdown]
# \* Note: all individual adjustments are either verified with instructions included in this dataset or with most common recipe available in the Internet.

# %%
df_cocktails = pd.read_csv('./raw_data/stage0.csv')
df_cocktails.drop('Unnamed: 0', axis=1, inplace=True)

df_cons = pd.read_csv('./raw_data/stage1.csv')
df_cons.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Function to print all ingredients with measures and instructions for given cocktail. Comes handy for spot check.

def recipe(name):
    ingredient = []
    measure = []
    for i in range (1, 13):
        ingredient.append(df_cocktails.loc[df_cocktails['strDrink'] == name]['strIngredient'+str(i)].values[0])
        measure.append(df_cocktails.loc[df_cocktails['strDrink'] == name]['strMeasure'+str(i)].values[0])
    df_recipe = pd.DataFrame({'Ingredient': ingredient, 'Measure': measure})
    
    print(df_cocktails.loc[df_cocktails['strDrink'] == name]['strInstructions'].values[0])
    return df_recipe

# %%
def repl_from_dic(dic, row):
    '''Function should be applied only on filtered data to avoid unexpected text values in field "Value".'''
    '''Dictionary might include only text that need to be explicitly translated to a number by a human.'''
    if row.Value in dic.keys():
        return dic[row.Value]
    else:
        try:
            number = float(Fraction(row.Value.split()[-1]))
            if len(row.Value.split()) > 1:
                return float(row.Value.split()[0])+number
            else:
                return number
        except (ValueError, AttributeError):
            pass
# print(repl_from_dic(values_replace, df_cons.iloc[23]))   # Test
# print(repl_from_dic(values_replace, df_cons.iloc[1]))
# print(repl_from_dic(values_replace, df_cons.iloc[2]))

# %%
print(len(df_cons['MeasureName'].unique()))
df_cons['MeasureName'].unique()
# Out:
# 121
# array(['white', 'oz', 'shot', 'bacardi', nan, 'dry', 'part', 'jigger',
#        'shots', 'bottle', 'cl', 'dashes', 'cup', 'scoops', 'hot',
#        'chopped', 'qt', 'parts', 'blue', 'ml', 'tsp', 'black', 'smirnoff',
#        'can', 'cubes', 'pint', 'pale', 'cups', 'superfine', 'fifth',
#        'large', 'instant', 'glass', 'l', 'hard', 'strip', 'jiggers',
#        'light', 'grape', 'handful', 'tblsp', '1/2', 'dark', 'jamaican',
#        'cream', 'chilled', 'bottles', 'measures', 'or', 'stoli', 'splash',
#        'dash', 'gr', 'red', 'ginger', 'lemon', 'quart', 'hill', 'slice',
#        'label', 'whole', '1', 'piece', 'tbsp', 'chunks', 'sweet', 'cold',
#        'packages', 'tropical', 'apple', 'blended', 'mild', 'cans',
#        'drops', 'with', 'of', '1/4', 'pure', 'cracked', 'frozen', 'gal',
#        'wedges', 'muscatel', 'leaves', 'skimmed', 'cube', 'taste',
#        'sweetened', 'needed)', 'wedge', 'double', 'splashes', 'spoons',
#        'unsweetened', 'top', 'one-inch', 'crushed', 'berry', 'topping',
#        'pinches', 'schweppes', '3', 'package', 'grated', 'fresh', 'lime',
#        'up', 'fill', 'tablespoons', 'green', 'boiling', 'pinch',
#        'hazlenut', 'strips', 'powdered', 'plain', 'ground', 'sprigs',
#        'yellow', 'sticks', 'granulated'], dtype=object)

# %% [markdown]
# Values will be converted to numberic in batches related to other characteristics, this way it's easier to process the mess and avoid mistakes.

# %%
df_cons.drop(df_cons.loc[(df_cons['strDrink'] == 'Swedish Coffee')
                         & (df_cons['MeasureName'] == 'taste')].index, axis=0, inplace=True)

df_cons.drop(df_cons.loc[(df_cons['strDrink']=='Kurant Tea') 
                         & (df_cons['MeasureName']=="needed)")].index, axis=0, inplace=True)

df_cons.drop(df_cons.loc[df_cons['strIngredients']=="Ice"].index, axis=0, inplace=True)

# %% [markdown]
# ## Converting measures to grams. <a class="anchor" id="1"></a>

# %%
df_cons['MeasureName'] = np.where((df_cons['strDrink'] == 'Adam Bomb') & (df_cons['MeasureName'] == 'pint'),
                                 'pinch', df_cons['MeasureName'])

# %%
dict_gr = {'chunks':30, 'gr':1, 'pinch':0.36, 'pinches':0.36, 'tsp':4, 'tblsp':14, 'cup':128, 'cube':4, 'piece':4, 'packages':90}
values_replace = {'1-3':2}
for key, value in dict_gr.items():
# First convert value as it is to numeric format
    df_cons['Value_numeric'] = np.where((df_cons['MeasureName'] == key) & (df_cons['Value_numeric'].isnull()),
                                        df_cons.apply(lambda row: repl_from_dic(values_replace, row), axis=1),
                                        df_cons['Value_numeric'])
# Then convert them to ml
    df_cons['Value_gr'] = np.where((df_cons['MeasureName'] == key) & (df_cons['Value_gr'].isnull()),
                                   df_cons['Value_numeric']*dict_gr[key],
                                   df_cons['Value_gr'])

# %%
# Processing all exceptionals from function in a cell above.

# %%
df_cons['Value_gr'] = np.where(df_cons['strIngredients'] == 'Banana', 120, df_cons['Value_gr'])

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Sugar') & (df_cons['MeasureName'].isnull())]
# Out:
#                    strDrink     strCategory             strGlass  \
# 1135  Classic Old-Fashioned  Ordinary Drink  Old-fashioned glass
# 1559             Lemon Shot            Shot           Shot glass
# 1671          Atomic Lokade  Ordinary Drink        Collins Glass
#
#      strIngredients                                    strInstructions  \
# 1135          Sugar  In an old-fashioned glass, muddle the bitters ...
# 1559          Sugar  Mix Galliano and Absolut Citron in a shot glas...
# 1671          Sugar  In a shaker, place lemonade, vodka, blue Curac...
#
#      strMeasures    Value MeasureName  Value_numeric  Value_ml  Value_gr  \
# 1135           1        1         NaN            NaN       NaN       NaN
# 1559     bacardi  bacardi         NaN            NaN       NaN       NaN
# 1671         NaN      NaN         NaN            NaN       NaN       NaN
#
#       Garnish_amount  Garnish_type MeasureName_copy
# 1135             NaN           NaN              NaN
# 1559             NaN           NaN              NaN
# 1671             NaN           NaN              NaN

# %%
cond1 = (df_cons['Value_ml'].isnull())
cond2 = (df_cons['Value_gr'].isnull())
cond3 = (df_cons['Garnish_type'].isnull())
print(len(df_cons.loc[cond1 & cond2 & cond3]['MeasureName']))
print(len(df_cons.loc[cond1 & cond2 & cond3]['MeasureName'].unique()))
df_cons.loc[cond1 & cond2 & cond3]['MeasureName'].unique()
# Out:
# 1681
# 111
# array(['white', 'oz', 'shot', 'bacardi', nan, 'dry', 'part', 'jigger',
#        'shots', 'bottle', 'cl', 'dashes', 'scoops', 'hot', 'chopped',
#        'qt', 'parts', 'blue', 'ml', 'black', 'smirnoff', 'can', 'pint',
#        'pale', 'cups', 'superfine', 'fifth', 'large', 'instant', 'glass',
#        'l', 'hard', 'strip', 'jiggers', 'light', 'grape', 'handful',
#        '1/2', 'dark', 'jamaican', 'cream', 'chilled', 'bottles',
#        'measures', 'or', 'stoli', 'splash', 'dash', 'red', 'ginger',
#        'lemon', 'quart', 'hill', 'slice', 'label', 'whole', '1', 'tbsp',
#        'sweet', 'cold', 'tropical', 'apple', 'blended', 'mild', 'cans',
#        'drops', 'cup', 'with', 'of', '1/4', 'pure', 'cracked', 'frozen',
#        'gal', 'wedges', 'muscatel', 'leaves', 'skimmed', 'taste',
#        'sweetened', 'wedge', 'double', 'tblsp', 'splashes', 'spoons',
#        'unsweetened', 'top', 'one-inch', 'berry', 'topping', 'schweppes',
#        'package', 'grated', 'crushed', 'fresh', 'lime', 'up', 'fill',
#        'tablespoons', 'green', 'boiling', 'pinch', 'hazlenut', 'strips',
#        'powdered', 'plain', 'ground', 'sprigs', 'yellow', 'sticks',
#        'granulated'], dtype=object)

# %% [markdown]
# ## Converting standard measures to ml.<a class="anchor" id="2"></a>

# %% [markdown]
# ## Some measures are ending up with description of a product, not the name of the measure.

# %%
# Separately as can't be fitted into loop below

df_cons['Value'] = np.where(df_cons['MeasureName'] == 'fifth', df_cons['Value']+'/5', df_cons['Value'])


df_cons['MeasureName'] = np.where((df_cons['strIngredients'].str.contains('Egg')) & (df_cons['Value_ml'].isnull()),
                                    'egg', df_cons['MeasureName'])


df_cons['Value_numeric'] = np.where((df_cons['strDrink'] == 'Artillery Punch')&(df_cons['MeasureName_copy'] == 'black'),
                               1, df_cons['Value_numeric'])
df_cons['MeasureName'] = np.where((df_cons['strDrink'] == 'Artillery Punch')&(df_cons['MeasureName'] == 'black'),
                               'quart', df_cons['MeasureName'])

df_cons['Value_numeric'] = np.where((df_cons['strDrink'] == 'Jamaican Coffee')&(df_cons['MeasureName_copy'] == 'black'),
                               1/6, df_cons['Value_numeric'])
df_cons['MeasureName'] = np.where((df_cons['strDrink'] == 'Jamaican Coffee')&(df_cons['MeasureName'] == 'black'),
                               'glass', df_cons['MeasureName'])

df_cons['Value'] = np.where((df_cons['MeasureName'] == 'pale'), '1', df_cons['Value'])
df_cons['MeasureName'] = np.where((df_cons['MeasureName'] == 'pale'), 'part', df_cons['MeasureName'])

# %%
df_cons['MeasureName'] = np.where(df_cons['MeasureName'].isin(['part', 'parts']), 'oz', df_cons['MeasureName'])

# %%
to_fix = ['white', 'dry', 'hot', 'blue', 'smirnoff', 'superfine', 'hard', 'light', 'grape', 'jamaican', 'cream', 'red', 'lemon',
          'cold', 'tropical', 'blended', 'frozen', 'muscatel', 'skimmed', 'double', 'sweetened', 'unsweetened', 'schweppes',
          'grated', 'fresh', 'hazlenut', 'plain', 'ground']

# %%
for i in to_fix:
    df_cons['strIngredients'] = np.where(df_cons['MeasureName'] == i,
                                         (df_cons['strIngredients']+' '+i.title()),
                                         df_cons['strIngredients'])
    
    df_cons['Value'] = np.where(df_cons['MeasureName'] == i,
                                 df_cons['Value'].str.rsplit(n=1, expand=True)[0],
                                 df_cons['Value'])
    
    df_cons['MeasureName'] = np.where(df_cons['MeasureName'] == i,
                                     df_cons['Value'].str.rsplit(n=1, expand=True)[1],
                                     df_cons['MeasureName'])

# %%
# Separately as we don't need to add key-words to ingredient's name

to_fix = ['bacardi', 'chilled', 'stoli', 'of']

for i in to_fix:
    df_cons['MeasureName'] = np.where(df_cons['MeasureName_copy'] == i,
                                     df_cons['Value'].str.rsplit(n=1, expand=True)[1],
                                     df_cons['MeasureName'])

    df_cons['Value'] = np.where(df_cons['MeasureName_copy'] == i,
                                 df_cons['Value'].str.rsplit(n=1, expand=True)[0],
                                 df_cons['Value'])

# %%
dic = {'dark':['Rub Light Or Dark', '2', 'oz'],
        'or':['White Or Red Wine', '2', 'oz'],
        'ginger':['Green Ginger Wine', '1', 'oz'],
       'hill':["Boone's Strawberry Hill Wine", '1', 'bottle'],
       'label':['Vodka Smirnoff Red Label', '1/5', 'bottle'],
       'apple':['Turkish Apple Tea', '1', 'cup'],
       'taste':['Lemon Juice', '1/2', 'oz'],
       'berry':['Kool-Aid Tropical Berry', '1', 'gal']}

for key, value in dic.items():
    df_cons['strIngredients'] = np.where(df_cons['MeasureName_copy'] == key, dic[key][0], df_cons['strIngredients'])
    df_cons['Value'] = np.where(df_cons['MeasureName_copy'] == key, dic[key][1], df_cons['Value'])
    df_cons['MeasureName'] = np.where(df_cons['MeasureName_copy'] == key, dic[key][2], df_cons['MeasureName'])

# %% [markdown]
# ## oz, cl, qt, ml, l, shot(s), pint, jigger(s), dash(es), drops, can(s), cup(s), spoons, glass, splash(es), scoops, measures, gal, dl<a class="anchor" id="3"></a>

# %%
df_cons['Value'] = np.where(df_cons['strMeasures'] == '1 1/2', '1 1/2', df_cons['Value'])

# %%
measures_dict = {'oz':30, 'cl':10, 'ml':1, 'shot':25, 'shots':25, 'pint':473, 'jigger':44, 'jiggers':44, 'dash':1, 'dashes':1,
                 'drops':1, 'can':330, 'cans':330, 'cup':237, 'cups':237, 'tblsp':15, 'tbsp':15, 'tablespoons':15, 'tsp':5,
                 'spoons':5, 'l':1000, 'qt':946, 'quart':946, 'glass':350, 'splash':6, 'splashes':6, 'scoops':60, 'measures':30,
                 'gal':3785, 'dl':100, 'package':60, 'fifth':750, 'egg':45, '1/2':25}

# %%
values_replace = {'2-3':2.5, '70ml/2fl':70, 'add 10':10, '3-4':3.5, '10-12':11, 'add 250':250, '1-2':1.5, '1-3':2,
                  'add 1/2':0.5, 'about 8':8, 'add':1, '8-10':9}

# %%
for key, value in measures_dict.items():
# First convert value as it is to numeric format
    df_cons['Value_numeric'] = np.where((df_cons['MeasureName'] == key) & (df_cons['Value_numeric'].isnull()),
                                        df_cons.apply(lambda row: repl_from_dic(values_replace, row), axis=1),
                                        df_cons['Value_numeric'])
# Then convert them to ml
    df_cons['Value_ml'] = np.where((df_cons['MeasureName'] == key)&(df_cons['Value_ml'].isnull())&(df_cons['Value_gr'].isnull()),
                                   df_cons['Value_numeric']*measures_dict[key],
                                   df_cons['Value_ml'])

# %% [markdown]
# ### Individual cases <a class="anchor" id="4"></a>

# %% [markdown]
# **Issues with 'glass' measure**

# %%
df_cons['Value_ml'] = np.where((df_cons['strDrink'] == 'Jamaican Coffee') & (df_cons['strIngredients'] == 'Rum'),
                                    180/6, df_cons['Value_ml'])

# %%
df_cons['Value_ml'] = np.where((df_cons['strDrink'] == 'Tequila Surprise') & (df_cons['MeasureName'] == 'glass'),
                                    44, df_cons['Value_ml'])

# %%
df_cons['Value_ml'] = np.where((df_cons['strDrink'] == 'Butter Baby') & (df_cons['strIngredients'] == 'Vanilla Ice-Cream'),
                                    60*2, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where((df_cons['strDrink'] == 'Butter Baby') & (df_cons['strIngredients'] == 'Butterscotch schnapps'),
                                    30, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where((df_cons['strDrink'] == 'Butter Baby') & (df_cons['strIngredients'] == 'Milk'),
                                    300, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where((df_cons['strDrink'] == 'Butter Baby') & (df_cons['strIngredients'] == 'Vodka'),
                                    30*2, df_cons['Value_ml'])

# %% [markdown]
# **Issues with 'bottle' measure**

# %%
df_cons['Value_ml'] = np.where((df_cons['strCategory'] == 'Beer') & (df_cons['MeasureName'] == 'bottle'),
                                    330, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where((df_cons['strCategory'] == 'Punch / Party Drink') & (df_cons['MeasureName'] == 'bottle'),
                                    750, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where((df_cons['strDrink'] == 'Brain Fart') & (df_cons['MeasureName'] == 'bottle'),
                                    125, df_cons['Value_ml'])

# %% [markdown]
# **Separate cocktails fixed individually**

# %%
# Snake Bite (UK)

df_cons['Value_ml'] = np.where((df_cons['strDrink'] == 'Snake Bite (UK)') & (df_cons['MeasureName_copy'] == 'dry'),
                                    473/2, df_cons['Value_ml'])
df_cons['strIngredients'] = np.where((df_cons['strDrink'] == 'Snake Bite (UK)') & (df_cons['MeasureName_copy'] == 'dry'),
                                    'Cider Sweet Or Dry', df_cons['strIngredients'])

# %%
# Snakebite and Black

df_cons['Value_ml'] = np.where((df_cons['MeasureName'] == 'bit'), 5, df_cons['Value_ml'])

# %%
# Herbal flame

df_cons['strIngredients'] = np.where((df_cons['MeasureName'] == 'sweet'), 'Very Sweet Tea', df_cons['strIngredients'])

# %% [markdown]
# ## Lemons.<a class="anchor" id="5"></a>

# %%
df_cons.loc[df_cons['strIngredients'] == 'Lemon']
# Out:
#                          strDrink          strCategory  \
# 509          A True Amaretto Sour             Cocktail
# 636                   Boston Sour       Ordinary Drink
# 647                   Brandy Sour       Ordinary Drink
# 658           California Lemonade       Ordinary Drink
# 731                      Gin Fizz       Ordinary Drink
# 733                     Gin Sling       Ordinary Drink
# 777                 Japanese Fizz       Ordinary Drink
# 835                 New York Sour       Ordinary Drink
# 875                Royal Gin Fizz       Ordinary Drink
# 929                  Tequila Sour       Ordinary Drink
# 956                  Whiskey Sour       Ordinary Drink
# 962                    Wine Punch  Punch / Party Drink
# 1111               Brandy Cobbler       Ordinary Drink
# 1130                 Chicago Fizz       Ordinary Drink
# 1137                  Clover Club       Ordinary Drink
# 1173                  Frisco Sour       Ordinary Drink
# 1185                   Gin Rickey             Cocktail
# 1214                Imperial Fizz       Ordinary Drink
# 1238                   Lemon Drop             Cocktail
# 1239                   Lemon Shot                 Shot
# 1292            Quaker's Cocktail       Ordinary Drink
# 1307                  Rum Cobbler       Ordinary Drink
# 1308                   Rum Cooler       Ordinary Drink
# 1320   Sangria - The World's Best  Punch / Party Drink
# 1335             Sidecar Cocktail       Ordinary Drink
# 1340                     Snowball       Ordinary Drink
# 1369                      Vesuvio       Ordinary Drink
# 1479                  Brandy Sour       Ordinary Drink
# 1501                Dirty Martini             Cocktail
# 1558               Lady Love Fizz       Ordinary Drink
# 1571   Mississippi Planters Punch       Ordinary Drink
# 1613                  Scotch Sour       Ordinary Drink
# 1616            Shanghai Cocktail       Ordinary Drink
# 1625          Sunny Holiday Punch  Punch / Party Drink
# 1630                 Tequila Sour       Ordinary Drink
# 1645               Zizi Coin-coin  Punch / Party Drink
# 1655           Absolut Summertime             Cocktail
# 1685                  Boston Sour       Ordinary Drink
# 1714                  Frisco Sour       Ordinary Drink
# 1740              Long Island Tea       Ordinary Drink
# 1752                New York Sour       Ordinary Drink
# 1791                 Whiskey Sour       Ordinary Drink
# 1809                 Bloody Maria       Ordinary Drink
# 1885                Sweet Sangria  Punch / Party Drink
# 1886                       Zoksel    Soft Drink / Soda
# 1901  3-Mile Long Island Iced Tea       Ordinary Drink
#
#                       strGlass strIngredients  \
# 509        Old-fashioned glass          Lemon
# 636         Whiskey sour glass          Lemon
# 647         Whiskey sour glass          Lemon
# 658              Collins glass          Lemon
# 731             Highball glass          Lemon
# 733        Old-fashioned glass          Lemon
# 777             Highball glass          Lemon
# 835         Whiskey sour glass          Lemon
# 875             Highball glass          Lemon
# 929         Whiskey sour glass          Lemon
# 956        Old-fashioned glass          Lemon
# 962              Collins Glass          Lemon
# 1111       Old-fashioned glass          Lemon
# 1130            Highball glass          Lemon
# 1137            Cocktail glass          Lemon
# 1173        Whiskey sour glass          Lemon
# 1185            Highball glass          Lemon
# 1214            Highball glass          Lemon
# 1238            Cocktail glass          Lemon
# 1239                Shot glass          Lemon
# 1292            Cocktail glass          Lemon
# 1307       Old-fashioned glass          Lemon
# 1308             Collins glass          Lemon
# 1320                   Pitcher          Lemon
# 1335            Cocktail glass          Lemon
# 1340            Highball glass          Lemon
# 1369       Old-fashioned glass          Lemon
# 1479        Whiskey sour glass          Lemon
# 1501            Cocktail glass          Lemon
# 1558            Cocktail glass          Lemon
# 1571             Collins glass          Lemon
# 1613        Whiskey sour glass          Lemon
# 1616            Cocktail glass          Lemon
# 1625                Punch bowl          Lemon
# 1630        Whiskey sour glass          Lemon
# 1645  Margarita/Coupette glass          Lemon
# 1655             Collins glass          Lemon
# 1685        Whiskey sour glass          Lemon
# 1714        Whiskey sour glass          Lemon
# 1740            Highball glass          Lemon
# 1752        Whiskey sour glass          Lemon
# 1791       Old-fashioned glass          Lemon
# 1809       Old-fashioned glass          Lemon
# 1885                   Pitcher          Lemon
# 1886              Beer pilsner          Lemon
# 1901             Collins Glass          Lemon
#
#                                         strInstructions       strMeasures  \
# 509   Rub the rim of an old fashioned glass with lem...      juice of 1/2
# 636   Shake juice of lemon, powdered sugar, blended ...      juice of 1/2
# 647   Shake brandy, juice of lemon, and powdered sug...      juice of 1/2
# 658   Shake all ingredients (except carbonated water...        juice of 1
# 731   Shake all ingredients with ice cubes, except s...      juice of 1/2
# 733   Dissolve powdered sugar in mixture of water an...      juice of 1/2
# 777   Shake all ingredients (except carbonated water...      juice of 1/2
# 835   Shake blended whiskey, juice of lemon, and pow...      juice of 1/2
# 875   Shake all ingredients (except carbonated water...      juice of 1/2
# 929   Shake tequila, juice of lemon, and powdered su...      juice of 1/2
# 956   Shake with ice. Strain into chilled glass, gar...      juice of 1/2
# 962   Combine all of the ingredients and pour over a...                 2
# 1111  In an old-fashioned glass, dissolve the sugar ...                 1
# 1130  Shake all ingredients (except carbonated water...      juice of 1/2
# 1137  Dry shake ingredients to emulsify, add ice, sh...      juice of 1/2
# 1173  Shake all ingredients (except slices of lemon ...      juice of 1/4
# 1185  Half-fill a tall glass with ice. Mix the gin a...      juice of 1/2
# 1214  Shake all ingredients (except carbonated water...      juice of 1/2
# 1238  Shake and strain into a chilled cocktail glass...  juice of 1 wedge
# 1239  Mix Galliano and Absolut Citron in a shot glas...             wedge
# 1292  Shake all ingredients with ice, strain into a ...      juice of 1/4
# 1307  In an old-fashioned glass, dissolve the sugar ...                 1
# 1308  Pour the rum and soda into a collins glass alm...                 1
# 1320  Mix wine, sugar and fruit, and let sit in the ...           1 large
# 1335  Shake all ingredients with ice, strain into a ...      juice of 1/4
# 1340  Place one ice cube in the glass and add 1 1/2 ...           1 slice
# 1369  Shake all ingredients with ice, strain into an...      juice of 1/2
# 1479  Shake brandy, juice of lemon, and powdered sug...         1/2 slice
# 1501  Pour the vodka, dry vermouth and olive brine i...           1 wedge
# 1558  Shake all ingredients (except carbonated water...      juice of 1/2
# 1571  Shake all ingredients (except carbonated water...      juice of 1/2
# 1613  Shake scotch, juice of lime, and powdered suga...         1/2 slice
# 1616  Shake all ingredients with ice, strain into a ...      juice of 1/4
# 1625           Combine all ingredients in a punch bowl.                 1
# 1630  Shake tequila, juice of lemon, and powdered su...         1/2 slice
# 1645  Pour 5cl of Cointreau on ice, add 2cl of fresh...           or lime
# 1655  Add all ingredients except lemon to shaker fil...           1 slice
# 1685  Shake juice of lemon, powdered sugar, blended ...           1 slice
# 1714  Shake all ingredients (except slices of lemon ...           1 slice
# 1740  Combine all ingredients (except cola) and pour...      juice of 1/2
# 1752  Shake blended whiskey, juice of lemon, and pow...               NaN
# 1791  Shake with ice. Strain into chilled glass, gar...         1/2 slice
# 1809  Shake all ingredients (except lemon slice) wit...           1 slice
# 1885  Dissolve the sugar in hot water and cool. Peel...               NaN
# 1886  No specific mixinginstructions, just poor ever...               NaN
# 1901  Fill 14oz glass with ice and alcohol. Fill 2/3...               NaN
#
#            Value MeasureName  Value_numeric  Value_ml  Value_gr  \
# 509     juice of         1/2            NaN       NaN       NaN
# 636     juice of         1/2            NaN       NaN       NaN
# 647     juice of         1/2            NaN       NaN       NaN
# 658     juice of           1            NaN       NaN       NaN
# 731     juice of         1/2            NaN       NaN       NaN
# 733     juice of         1/2            NaN       NaN       NaN
# 777     juice of         1/2            NaN       NaN       NaN
# 835     juice of         1/2            NaN       NaN       NaN
# 875     juice of         1/2            NaN       NaN       NaN
# 929     juice of         1/2            NaN       NaN       NaN
# 956     juice of         1/2            NaN       NaN       NaN
# 962            2         NaN            NaN       NaN       NaN
# 1111           1         NaN            NaN       NaN       NaN
# 1130    juice of         1/2            NaN       NaN       NaN
# 1137    juice of         1/2            NaN       NaN       NaN
# 1173    juice of         1/4            NaN       NaN       NaN
# 1185    juice of         1/2            NaN       NaN       NaN
# 1214    juice of         1/2            NaN       NaN       NaN
# 1238  juice of 1       wedge            NaN       NaN       NaN
# 1239       wedge         NaN            NaN       NaN       NaN
# 1292    juice of         1/4            NaN       NaN       NaN
# 1307           1         NaN            NaN       NaN       NaN
# 1308           1         NaN            NaN       NaN       NaN
# 1320           1       large            NaN       NaN       NaN
# 1335    juice of         1/4            NaN       NaN       NaN
# 1340           1       slice            NaN       NaN       NaN
# 1369    juice of         1/2            NaN       NaN       NaN
# 1479         1/2       slice            NaN       NaN       NaN
# 1501           1       wedge            NaN       NaN       NaN
# 1558    juice of         1/2            NaN       NaN       NaN
# 1571    juice of         1/2            NaN       NaN       NaN
# 1613         1/2       slice            NaN       NaN       NaN
# 1616    juice of         1/4            NaN       NaN       NaN
# 1625           1         NaN            NaN       NaN       NaN
# 1630         1/2       slice            NaN       NaN       NaN
# 1645          or        lime            NaN       NaN       NaN
# 1655           1       slice            NaN       NaN       NaN
# 1685           1       slice            NaN       NaN       NaN
# 1714           1       slice            NaN       NaN       NaN
# 1740    juice of         1/2            NaN       NaN       NaN
# 1752         NaN         NaN            NaN       NaN       NaN
# 1791         1/2       slice            NaN       NaN       NaN
# 1809           1       slice            NaN       NaN       NaN
# 1885         NaN         NaN            NaN       NaN       NaN
# 1886         NaN         NaN            NaN       NaN       NaN
# 1901         NaN         NaN            NaN       NaN       NaN
#
#       Garnish_amount  Garnish_type MeasureName_copy
# 509              NaN           NaN              1/2
# 636              NaN           NaN              1/2
# 647              NaN           NaN              1/2
# 658              NaN           NaN                1
# 731              NaN           NaN              1/2
# 733              NaN           NaN              1/2
# 777              NaN           NaN              1/2
# 835              NaN           NaN              1/2
# 875              NaN           NaN              1/2
# 929              NaN           NaN              1/2
# 956              NaN           NaN              1/2
# 962              NaN           NaN              NaN
# 1111             NaN           NaN              NaN
# 1130             NaN           NaN              1/2
# 1137             NaN           NaN              1/2
# 1173             NaN           NaN              1/4
# 1185             NaN           NaN              1/2
# 1214             NaN           NaN              1/2
# 1238             NaN           NaN            wedge
# 1239             NaN           NaN              NaN
# 1292             NaN           NaN              1/4
# 1307             NaN           NaN              NaN
# 1308             NaN           NaN              NaN
# 1320             NaN           NaN            large
# 1335             NaN           NaN              1/4
# 1340             NaN           NaN            slice
# 1369             NaN           NaN              1/2
# 1479             NaN           NaN            slice
# 1501             NaN           NaN            wedge
# 1558             NaN           NaN              1/2
# 1571             NaN           NaN              1/2
# 1613             NaN           NaN            slice
# 1616             NaN           NaN              1/4
# 1625             NaN           NaN              NaN
# 1630             NaN           NaN            slice
# 1645             NaN           NaN             lime
# 1655             NaN           NaN            slice
# 1685             NaN           NaN            slice
# 1714             NaN           NaN            slice
# 1740             NaN           NaN              1/2
# 1752             NaN           NaN              NaN
# 1791             NaN           NaN            slice
# 1809             NaN           NaN            slice
# 1885             NaN           NaN              NaN
# 1886             NaN           NaN              NaN
# 1901             NaN           NaN              NaN

# %%
cond1 = df_cons['strIngredients'] == 'Lemon'
cond2 = df_cons['Value'] == 'juice of'
cond3 = df_cons['MeasureName'] == '1'
cond4 = df_cons['MeasureName'] == '1/2'
cond5 = df_cons['MeasureName'] == '1/4'

df_cons['Value_ml'] = np.where(cond1 & cond2 & cond3, 45, df_cons['Value_ml'])  #45 is aprox amount of ml of juice in 1 lemon
df_cons['Value_ml'] = np.where(cond1 & cond2 & cond4, 45/2, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where(cond1 & cond2 & cond5, 45/4, df_cons['Value_ml'])

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Lemon') & df_cons['Value_ml'].isnull()]
# Out:
#                          strDrink          strCategory  \
# 962                    Wine Punch  Punch / Party Drink
# 1111               Brandy Cobbler       Ordinary Drink
# 1238                   Lemon Drop             Cocktail
# 1239                   Lemon Shot                 Shot
# 1307                  Rum Cobbler       Ordinary Drink
# 1308                   Rum Cooler       Ordinary Drink
# 1320   Sangria - The World's Best  Punch / Party Drink
# 1340                     Snowball       Ordinary Drink
# 1479                  Brandy Sour       Ordinary Drink
# 1501                Dirty Martini             Cocktail
# 1613                  Scotch Sour       Ordinary Drink
# 1625          Sunny Holiday Punch  Punch / Party Drink
# 1630                 Tequila Sour       Ordinary Drink
# 1645               Zizi Coin-coin  Punch / Party Drink
# 1655           Absolut Summertime             Cocktail
# 1685                  Boston Sour       Ordinary Drink
# 1714                  Frisco Sour       Ordinary Drink
# 1752                New York Sour       Ordinary Drink
# 1791                 Whiskey Sour       Ordinary Drink
# 1809                 Bloody Maria       Ordinary Drink
# 1885                Sweet Sangria  Punch / Party Drink
# 1886                       Zoksel    Soft Drink / Soda
# 1901  3-Mile Long Island Iced Tea       Ordinary Drink
#
#                       strGlass strIngredients  \
# 962              Collins Glass          Lemon
# 1111       Old-fashioned glass          Lemon
# 1238            Cocktail glass          Lemon
# 1239                Shot glass          Lemon
# 1307       Old-fashioned glass          Lemon
# 1308             Collins glass          Lemon
# 1320                   Pitcher          Lemon
# 1340            Highball glass          Lemon
# 1479        Whiskey sour glass          Lemon
# 1501            Cocktail glass          Lemon
# 1613        Whiskey sour glass          Lemon
# 1625                Punch bowl          Lemon
# 1630        Whiskey sour glass          Lemon
# 1645  Margarita/Coupette glass          Lemon
# 1655             Collins glass          Lemon
# 1685        Whiskey sour glass          Lemon
# 1714        Whiskey sour glass          Lemon
# 1752        Whiskey sour glass          Lemon
# 1791       Old-fashioned glass          Lemon
# 1809       Old-fashioned glass          Lemon
# 1885                   Pitcher          Lemon
# 1886              Beer pilsner          Lemon
# 1901             Collins Glass          Lemon
#
#                                         strInstructions       strMeasures  \
# 962   Combine all of the ingredients and pour over a...                 2
# 1111  In an old-fashioned glass, dissolve the sugar ...                 1
# 1238  Shake and strain into a chilled cocktail glass...  juice of 1 wedge
# 1239  Mix Galliano and Absolut Citron in a shot glas...             wedge
# 1307  In an old-fashioned glass, dissolve the sugar ...                 1
# 1308  Pour the rum and soda into a collins glass alm...                 1
# 1320  Mix wine, sugar and fruit, and let sit in the ...           1 large
# 1340  Place one ice cube in the glass and add 1 1/2 ...           1 slice
# 1479  Shake brandy, juice of lemon, and powdered sug...         1/2 slice
# 1501  Pour the vodka, dry vermouth and olive brine i...           1 wedge
# 1613  Shake scotch, juice of lime, and powdered suga...         1/2 slice
# 1625           Combine all ingredients in a punch bowl.                 1
# 1630  Shake tequila, juice of lemon, and powdered su...         1/2 slice
# 1645  Pour 5cl of Cointreau on ice, add 2cl of fresh...           or lime
# 1655  Add all ingredients except lemon to shaker fil...           1 slice
# 1685  Shake juice of lemon, powdered sugar, blended ...           1 slice
# 1714  Shake all ingredients (except slices of lemon ...           1 slice
# 1752  Shake blended whiskey, juice of lemon, and pow...               NaN
# 1791  Shake with ice. Strain into chilled glass, gar...         1/2 slice
# 1809  Shake all ingredients (except lemon slice) wit...           1 slice
# 1885  Dissolve the sugar in hot water and cool. Peel...               NaN
# 1886  No specific mixinginstructions, just poor ever...               NaN
# 1901  Fill 14oz glass with ice and alcohol. Fill 2/3...               NaN
#
#            Value MeasureName  Value_numeric  Value_ml  Value_gr  \
# 962            2         NaN            NaN       NaN       NaN
# 1111           1         NaN            NaN       NaN       NaN
# 1238  juice of 1       wedge            NaN       NaN       NaN
# 1239       wedge         NaN            NaN       NaN       NaN
# 1307           1         NaN            NaN       NaN       NaN
# 1308           1         NaN            NaN       NaN       NaN
# 1320           1       large            NaN       NaN       NaN
# 1340           1       slice            NaN       NaN       NaN
# 1479         1/2       slice            NaN       NaN       NaN
# 1501           1       wedge            NaN       NaN       NaN
# 1613         1/2       slice            NaN       NaN       NaN
# 1625           1         NaN            NaN       NaN       NaN
# 1630         1/2       slice            NaN       NaN       NaN
# 1645          or        lime            NaN       NaN       NaN
# 1655           1       slice            NaN       NaN       NaN
# 1685           1       slice            NaN       NaN       NaN
# 1714           1       slice            NaN       NaN       NaN
# 1752         NaN         NaN            NaN       NaN       NaN
# 1791         1/2       slice            NaN       NaN       NaN
# 1809           1       slice            NaN       NaN       NaN
# 1885         NaN         NaN            NaN       NaN       NaN
# 1886         NaN         NaN            NaN       NaN       NaN
# 1901         NaN         NaN            NaN       NaN       NaN
#
#       Garnish_amount  Garnish_type MeasureName_copy
# 962              NaN           NaN              NaN
# 1111             NaN           NaN              NaN
# 1238             NaN           NaN            wedge
# 1239             NaN           NaN              NaN
# 1307             NaN           NaN              NaN
# 1308             NaN           NaN              NaN
# 1320             NaN           NaN            large
# 1340             NaN           NaN            slice
# 1479             NaN           NaN            slice
# 1501             NaN           NaN            wedge
# 1613             NaN           NaN            slice
# 1625             NaN           NaN              NaN
# 1630             NaN           NaN            slice
# 1645             NaN           NaN             lime
# 1655             NaN           NaN            slice
# 1685             NaN           NaN            slice
# 1714             NaN           NaN            slice
# 1752             NaN           NaN              NaN
# 1791             NaN           NaN            slice
# 1809             NaN           NaN            slice
# 1885             NaN           NaN              NaN
# 1886             NaN           NaN              NaN
# 1901             NaN           NaN              NaN

# %%
cond1 = df_cons['strIngredients'] == 'Lemon'
cond2 = df_cons['MeasureName'].isnull()
cond3 = df_cons['MeasureName'] == 'large'
cond4 = df_cons['Value'] == '1'
cond5 = df_cons['Value'] == '2'
cond6 = df_cons['Value'] == '1/2'
cond7 = df_cons['MeasureName'] == 'lime'

df_cons['Value_ml'] = np.where(cond1 & (cond2 | cond3) & cond4, 45, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where(cond1 & (cond2 | cond3) & cond5, 45*2, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where(cond1 & (cond2 | cond3) & cond6, 45/2, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where(cond1 & cond7, 20, df_cons['Value_ml'])  # Recipe verified via Internet manually

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Lemon') & df_cons['Value_ml'].isnull()]
# Out:
#                          strDrink          strCategory             strGlass  \
# 1238                   Lemon Drop             Cocktail       Cocktail glass
# 1239                   Lemon Shot                 Shot           Shot glass
# 1340                     Snowball       Ordinary Drink       Highball glass
# 1479                  Brandy Sour       Ordinary Drink   Whiskey sour glass
# 1501                Dirty Martini             Cocktail       Cocktail glass
# 1613                  Scotch Sour       Ordinary Drink   Whiskey sour glass
# 1630                 Tequila Sour       Ordinary Drink   Whiskey sour glass
# 1655           Absolut Summertime             Cocktail        Collins glass
# 1685                  Boston Sour       Ordinary Drink   Whiskey sour glass
# 1714                  Frisco Sour       Ordinary Drink   Whiskey sour glass
# 1752                New York Sour       Ordinary Drink   Whiskey sour glass
# 1791                 Whiskey Sour       Ordinary Drink  Old-fashioned glass
# 1809                 Bloody Maria       Ordinary Drink  Old-fashioned glass
# 1885                Sweet Sangria  Punch / Party Drink              Pitcher
# 1886                       Zoksel    Soft Drink / Soda         Beer pilsner
# 1901  3-Mile Long Island Iced Tea       Ordinary Drink        Collins Glass
#
#      strIngredients                                    strInstructions  \
# 1238          Lemon  Shake and strain into a chilled cocktail glass...
# 1239          Lemon  Mix Galliano and Absolut Citron in a shot glas...
# 1340          Lemon  Place one ice cube in the glass and add 1 1/2 ...
# 1479          Lemon  Shake brandy, juice of lemon, and powdered sug...
# 1501          Lemon  Pour the vodka, dry vermouth and olive brine i...
# 1613          Lemon  Shake scotch, juice of lime, and powdered suga...
# 1630          Lemon  Shake tequila, juice of lemon, and powdered su...
# 1655          Lemon  Add all ingredients except lemon to shaker fil...
# 1685          Lemon  Shake juice of lemon, powdered sugar, blended ...
# 1714          Lemon  Shake all ingredients (except slices of lemon ...
# 1752          Lemon  Shake blended whiskey, juice of lemon, and pow...
# 1791          Lemon  Shake with ice. Strain into chilled glass, gar...
# 1809          Lemon  Shake all ingredients (except lemon slice) wit...
# 1885          Lemon  Dissolve the sugar in hot water and cool. Peel...
# 1886          Lemon  No specific mixinginstructions, just poor ever...
# 1901          Lemon  Fill 14oz glass with ice and alcohol. Fill 2/3...
#
#            strMeasures       Value MeasureName  Value_numeric  Value_ml  \
# 1238  juice of 1 wedge  juice of 1       wedge            NaN       NaN
# 1239             wedge       wedge         NaN            NaN       NaN
# 1340           1 slice           1       slice            NaN       NaN
# 1479         1/2 slice         1/2       slice            NaN       NaN
# 1501           1 wedge           1       wedge            NaN       NaN
# 1613         1/2 slice         1/2       slice            NaN       NaN
# 1630         1/2 slice         1/2       slice            NaN       NaN
# 1655           1 slice           1       slice            NaN       NaN
# 1685           1 slice           1       slice            NaN       NaN
# 1714           1 slice           1       slice            NaN       NaN
# 1752               NaN         NaN         NaN            NaN       NaN
# 1791         1/2 slice         1/2       slice            NaN       NaN
# 1809           1 slice           1       slice            NaN       NaN
# 1885               NaN         NaN         NaN            NaN       NaN
# 1886               NaN         NaN         NaN            NaN       NaN
# 1901               NaN         NaN         NaN            NaN       NaN
#
#       Value_gr  Garnish_amount  Garnish_type MeasureName_copy
# 1238       NaN             NaN           NaN            wedge
# 1239       NaN             NaN           NaN              NaN
# 1340       NaN             NaN           NaN            slice
# 1479       NaN             NaN           NaN            slice
# 1501       NaN             NaN           NaN            wedge
# 1613       NaN             NaN           NaN            slice
# 1630       NaN             NaN           NaN            slice
# 1655       NaN             NaN           NaN            slice
# 1685       NaN             NaN           NaN            slice
# 1714       NaN             NaN           NaN            slice
# 1752       NaN             NaN           NaN              NaN
# 1791       NaN             NaN           NaN            slice
# 1809       NaN             NaN           NaN            slice
# 1885       NaN             NaN           NaN              NaN
# 1886       NaN             NaN           NaN              NaN
# 1901       NaN             NaN           NaN              NaN

# %%
df_cons.loc[df_cons['MeasureName'] == 'wedge']
# Out:
#                          strDrink     strCategory             strGlass  \
# 1238                   Lemon Drop        Cocktail       Cocktail glass
# 1501                Dirty Martini        Cocktail       Cocktail glass
# 1810                  Bloody Mary  Ordinary Drink  Old-fashioned glass
# 1889  3-Mile Long Island Iced Tea  Ordinary Drink        Collins Glass
# 1904              Arizona Twister        Cocktail      Hurricane glass
#
#      strIngredients                                    strInstructions  \
# 1238          Lemon  Shake and strain into a chilled cocktail glass...
# 1501          Lemon  Pour the vodka, dry vermouth and olive brine i...
# 1810           Lime  Stirring gently, pour all ingredients into hig...
# 1889        Bitters  Fill 14oz glass with ice and alcohol. Fill 2/3...
# 1904      Pineapple  Just mix in the shots of rum, vodka, and tequi...
#
#            strMeasures       Value MeasureName  Value_numeric  Value_ml  \
# 1238  juice of 1 wedge  juice of 1       wedge            NaN       NaN
# 1501           1 wedge           1       wedge            NaN       NaN
# 1810           1 wedge           1       wedge            NaN       NaN
# 1889           1 wedge           1       wedge            NaN       NaN
# 1904           1 wedge           1       wedge            NaN       NaN
#
#       Value_gr  Garnish_amount  Garnish_type MeasureName_copy
# 1238       NaN             NaN           NaN            wedge
# 1501       NaN             NaN           NaN            wedge
# 1810       NaN             NaN           NaN            wedge
# 1889       NaN             NaN           NaN            wedge
# 1904       NaN             NaN           NaN            wedge

# %%
df_cons.loc[df_cons['MeasureName'] == 'slice']
# Out:
#                 strDrink        strCategory             strGlass  \
# 623     Bleeding Surgeon  Soft Drink / Soda        Collins glass
# 1340            Snowball     Ordinary Drink       Highball glass
# 1479         Brandy Sour     Ordinary Drink   Whiskey sour glass
# 1612      Scotch Cobbler     Ordinary Drink  Old-fashioned glass
# 1613         Scotch Sour     Ordinary Drink   Whiskey sour glass
# 1630        Tequila Sour     Ordinary Drink   Whiskey sour glass
# 1655  Absolut Summertime           Cocktail        Collins glass
# 1685         Boston Sour     Ordinary Drink   Whiskey sour glass
# 1714         Frisco Sour     Ordinary Drink   Whiskey sour glass
# 1721           Gin Smash     Ordinary Drink  Old-fashioned glass
# 1730        Irish Spring     Ordinary Drink        Collins glass
# 1789     Victory Collins     Ordinary Drink        Collins glass
# 1791        Whiskey Sour     Ordinary Drink  Old-fashioned glass
# 1809        Bloody Maria     Ordinary Drink  Old-fashioned glass
# 1828         Frisco Sour     Ordinary Drink   Whiskey sour glass
#
#      strIngredients                                    strInstructions  \
# 623          Orange  Pour Shot of Rum over slice of orange. Fill th...
# 1340          Lemon  Place one ice cube in the glass and add 1 1/2 ...
# 1479          Lemon  Shake brandy, juice of lemon, and powdered sug...
# 1612         Orange  Pour scotch, brandy, and curacao over ice in a...
# 1613          Lemon  Shake scotch, juice of lime, and powdered suga...
# 1630          Lemon  Shake tequila, juice of lemon, and powdered su...
# 1655          Lemon  Add all ingredients except lemon to shaker fil...
# 1685          Lemon  Shake juice of lemon, powdered sugar, blended ...
# 1714          Lemon  Shake all ingredients (except slices of lemon ...
# 1721         Orange  Muddle sugar with carbonated water and mint sp...
# 1730         Orange  Pour all ingredients (except orange slice and ...
# 1789         Orange  Shake all ingredients (except orange slice) wi...
# 1791          Lemon  Shake with ice. Strain into chilled glass, gar...
# 1809          Lemon  Shake all ingredients (except lemon slice) wit...
# 1828           Lime  Shake all ingredients (except slices of lemon ...
#
#      strMeasures Value MeasureName  Value_numeric  Value_ml  Value_gr  \
# 623      1 slice     1       slice            NaN       NaN       NaN
# 1340     1 slice     1       slice            NaN       NaN       NaN
# 1479   1/2 slice   1/2       slice            NaN       NaN       NaN
# 1612     1 slice     1       slice            NaN       NaN       NaN
# 1613   1/2 slice   1/2       slice            NaN       NaN       NaN
# 1630   1/2 slice   1/2       slice            NaN       NaN       NaN
# 1655     1 slice     1       slice            NaN       NaN       NaN
# 1685     1 slice     1       slice            NaN       NaN       NaN
# 1714     1 slice     1       slice            NaN       NaN       NaN
# 1721     1 slice     1       slice            NaN       NaN       NaN
# 1730     1 slice     1       slice            NaN       NaN       NaN
# 1789     1 slice     1       slice            NaN       NaN       NaN
# 1791   1/2 slice   1/2       slice            NaN       NaN       NaN
# 1809     1 slice     1       slice            NaN       NaN       NaN
# 1828     1 slice     1       slice            NaN       NaN       NaN
#
#       Garnish_amount  Garnish_type MeasureName_copy
# 623              NaN           NaN            slice
# 1340             NaN           NaN            slice
# 1479             NaN           NaN            slice
# 1612             NaN           NaN            slice
# 1613             NaN           NaN            slice
# 1630             NaN           NaN            slice
# 1655             NaN           NaN            slice
# 1685             NaN           NaN            slice
# 1714             NaN           NaN            slice
# 1721             NaN           NaN            slice
# 1730             NaN           NaN            slice
# 1789             NaN           NaN            slice
# 1791             NaN           NaN            slice
# 1809             NaN           NaN            slice
# 1828             NaN           NaN            slice

# %%
cond1 = df_cons['strIngredients'] == 'Lemon'
cond2 = df_cons['strDrink'] == 'Lemon Drop'
df_cons['Value_ml'] = np.where(cond1 & cond2, 45/2, df_cons['Value_ml']) # Although it says juice of 1 wedge, most common recipe
                                                                        # is to use juice of 1/2 of lemon.

# %%
cond1 = df_cons['MeasureName'].isin(['slice', 'wedge'])
cond2 = ~df_cons['strDrink'].isin(['Lemon Drop', '3-Mile Long Island Iced Tea'])

df_cons['Garnish_type'] = np.where(cond1 & cond2, df_cons['MeasureName'], df_cons['Garnish_type'])
df_cons['Garnish_amount'] = np.where(cond1 & cond2, df_cons['Value'], df_cons['Garnish_amount'])

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Lemon') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()]
# Out:
#                          strDrink          strCategory            strGlass  \
# 1239                   Lemon Shot                 Shot          Shot glass
# 1752                New York Sour       Ordinary Drink  Whiskey sour glass
# 1885                Sweet Sangria  Punch / Party Drink             Pitcher
# 1886                       Zoksel    Soft Drink / Soda        Beer pilsner
# 1901  3-Mile Long Island Iced Tea       Ordinary Drink       Collins Glass
#
#      strIngredients                                    strInstructions  \
# 1239          Lemon  Mix Galliano and Absolut Citron in a shot glas...
# 1752          Lemon  Shake blended whiskey, juice of lemon, and pow...
# 1885          Lemon  Dissolve the sugar in hot water and cool. Peel...
# 1886          Lemon  No specific mixinginstructions, just poor ever...
# 1901          Lemon  Fill 14oz glass with ice and alcohol. Fill 2/3...
#
#      strMeasures  Value MeasureName  Value_numeric  Value_ml  Value_gr  \
# 1239       wedge  wedge         NaN            NaN       NaN       NaN
# 1752         NaN    NaN         NaN            NaN       NaN       NaN
# 1885         NaN    NaN         NaN            NaN       NaN       NaN
# 1886         NaN    NaN         NaN            NaN       NaN       NaN
# 1901         NaN    NaN         NaN            NaN       NaN       NaN
#
#      Garnish_amount Garnish_type MeasureName_copy
# 1239            NaN          NaN              NaN
# 1752            NaN          NaN              NaN
# 1885            NaN          NaN              NaN
# 1886            NaN          NaN              NaN
# 1901            NaN          NaN              NaN

# %%
df_cons.loc[df_cons['strDrink'] == 'Lemon Shot']
# Out:
#         strDrink strCategory    strGlass  strIngredients  \
# 310   Lemon Shot        Shot  Shot glass        Galliano
# 798   Lemon Shot        Shot  Shot glass  Absolut Citron
# 1239  Lemon Shot        Shot  Shot glass           Lemon
# 1559  Lemon Shot        Shot  Shot glass           Sugar
# 1737  Lemon Shot        Shot  Shot glass   151 Proof Rum
#
#                                         strInstructions strMeasures    Value  \
# 310   Mix Galliano and Absolut Citron in a shot glas...      1/2 oz      1/2
# 798   Mix Galliano and Absolut Citron in a shot glas...      1/2 oz      1/2
# 1239  Mix Galliano and Absolut Citron in a shot glas...       wedge    wedge
# 1559  Mix Galliano and Absolut Citron in a shot glas...     bacardi  bacardi
# 1737  Mix Galliano and Absolut Citron in a shot glas...         NaN      NaN
#
#      MeasureName  Value_numeric  Value_ml  Value_gr Garnish_amount  \
# 310           oz            0.5      15.0       NaN            NaN
# 798           oz            0.5      15.0       NaN            NaN
# 1239         NaN            NaN       NaN       NaN            NaN
# 1559         NaN            NaN       NaN       NaN            NaN
# 1737         NaN            NaN       NaN       NaN            NaN
#
#      Garnish_type MeasureName_copy
# 310           NaN               oz
# 798           NaN               oz
# 1239          NaN              NaN
# 1559          NaN              NaN
# 1737          NaN              NaN

# %%
cond1 = df_cons['strIngredients'] == 'Lemon'
cond2 = df_cons['strDrink'] == 'Lemon Shot'
df_cons['Garnish_amount'] = np.where(cond1 & cond2, 1, df_cons['Garnish_amount'])
df_cons['Garnish_type'] = np.where(cond1 & cond2, 'wedge', df_cons['Garnish_type'])

# %%
cond1 = df_cons['strIngredients'] == 'Lemon'
cond2 = df_cons['strDrink'] == 'New York Sour'
df_cons['Garnish_amount'] = np.where(cond1 & cond2, '1/2', df_cons['Garnish_amount'])
df_cons['Garnish_type'] = np.where(cond1 & cond2, 'slice', df_cons['Garnish_type'])

# %% [markdown]
# Check remaining cocktails one by one.

# %%
recipe('Sweet Sangria')
# Out:
# Dissolve the sugar in hot water and cool. Peel the citrus fruits and break into wedges. Mix the wine, sugar syrup, fruit, and Fresca in a pitcher and put in the fridge for a few hours. Serve in tall glasses with a straw.
#    Ingredient      Measure
# 0    Red wine   2 bottles
# 1       Sugar       1 cup
# 2       Water  2 cups hot
# 3       Apple       1 cup
# 4      Orange     wedges\n
# 5        Lime     wedges\n
# 6       Lemon          NaN
# 7      Fresca          NaN
# 8         NaN          NaN
# 9         NaN          NaN
# 10        NaN          NaN
# 11        NaN          NaN

# %%
# Should be dropped as measures are too messy and it's impossible to recover original recipe.
df_cons.drop(df_cons.loc[df_cons['strDrink'] == 'Sweet Sangria'].index, axis=0, inplace=True)

# %%
recipe('Zoksel')
# Out:
# No specific mixinginstructions, just poor every ingredient in one glass. The lemon goes with it.
#          Ingredient   Measure
# 0              Beer       NaN
# 1         Root beer       NaN
# 2          Lemonade       NaN
# 3         Coca-Cola   slice\n
# 4              7-Up       NaN
# 5   Creme de Cassis       NaN
# 6             Lemon       NaN
# 7               NaN       NaN
# 8               NaN       NaN
# 9               NaN       NaN
# 10              NaN       NaN
# 11              NaN       NaN

# %%
# This cocktail should be dropped due to lack of guidance.

df_cons.drop(df_cons.loc[df_cons['strDrink'] == 'Zoksel'].index, axis=0, inplace=True)

# %%
recipe('3-Mile Long Island Iced Tea')
# Out:
# Fill 14oz glass with ice and alcohol. Fill 2/3 glass with cola and remainder with sweet & sour. Top with dash of bitters and lemon wedge.
#         Ingredient    Measure
# 0              Gin    1/2 oz
# 1        Light rum    1/2 oz
# 2          Tequila    1/2 oz
# 3       Triple sec    1/2 oz
# 4            Vodka    1/2 oz
# 5        Coca-Cola        NaN
# 6   Sweet and sour  1-2 dash
# 7          Bitters   1 wedge
# 8            Lemon        NaN
# 9              NaN        NaN
# 10             NaN        NaN
# 11             NaN        NaN

# %%
# Measures of this cocktail shifted, also some measures are missing.

cond1 = df_cons['strDrink'] == '3-Mile Long Island Iced Tea'

df_cons['Value_ml'] = np.where(cond1 & (df_cons['strIngredients'] == 'Coca-Cola'), 200, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where(cond1 & (df_cons['strIngredients'] == 'Sweet And Sour'), 30, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where(cond1 & (df_cons['strIngredients'] == 'Bitters'), 1, df_cons['Value_ml'])
df_cons['Garnish_amount'] = np.where(cond1 & (df_cons['strIngredients'] == 'Lemon'), 1, df_cons['Garnish_amount'])
df_cons['Garnish_type'] = np.where(cond1 & (df_cons['strIngredients'] == 'Lemon'), 'wedge', df_cons['Garnish_type'])

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Lemon') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()]
# We're done with lemon and can move on.
# Out:
# Empty DataFrame
# Columns: [strDrink, strCategory, strGlass, strIngredients, strInstructions, strMeasures, Value, MeasureName, Value_numeric, Value_ml, Value_gr, Garnish_amount, Garnish_type, MeasureName_copy]
# Index: []

# %% [markdown]
# ## Limes.<a class="anchor" id="6"></a>

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Lime') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()]
# Out:
#                    strDrink     strCategory             strGlass  \
# 169            Caipirissima  Ordinary Drink        Collins Glass
# 560           Amaretto Mist  Ordinary Drink  Old-fashioned glass
# 656              Caipirinha  Ordinary Drink  Old-fashioned glass
# 684              Cuba Libra  Ordinary Drink       Highball glass
# 685              Cuba Libre  Ordinary Drink       Highball glass
# 686                Daiquiri  Ordinary Drink       Cocktail glass
# 689         Dark Caipirinha        Cocktail       Highball glass
# 806              Long vodka  Ordinary Drink       Highball glass
# 823                  Mojito        Cocktail       Highball glass
# 895             Scotch Sour  Ordinary Drink   Whiskey sour glass
# 1023  After Dinner Cocktail  Ordinary Drink       Cocktail glass
# 1086             Bible Belt   Other/Unknown       Highball glass
# 1122    California Lemonade  Ordinary Drink        Collins glass
# 1141   Cosmopolitan Martini        Cocktail       Cocktail Glass
# 1154              Dragonfly  Ordinary Drink       Highball glass
# 1181          Gin And Tonic  Ordinary Drink       Highball glass
# 1203          Happy Skipper  Ordinary Drink       Highball glass
# 1220     Jack Rose Cocktail  Ordinary Drink       Cocktail glass
# 1293  Quarter Deck Cocktail  Ordinary Drink       Cocktail glass
# 1422  After Dinner Cocktail  Ordinary Drink       Cocktail glass
# 1437             Archbishop  Ordinary Drink  Old-fashioned glass
# 1469         Boston Sidecar  Ordinary Drink       Cocktail glass
# 1515            Frisco Sour  Ordinary Drink   Whiskey sour glass
# 1719             Gin Rickey        Cocktail       Highball glass
#
#      strIngredients                                    strInstructions  \
# 169            Lime  Same as Caipirinha but instead of cachaca you ...
# 560            Lime  Pour amaretto in an old-fashioned glass over c...
# 656            Lime  Place lime and sugar into old fashioned glass ...
# 684            Lime  Fill tall glass with ice cubes. Add rum. Rub c...
# 685            Lime  Build all ingredients in a Collins glass fille...
# 686            Lime  Pour all ingredients into shaker with ice cube...
# 689            Lime  Muddle the sugar into the lime wedges in an ol...
# 806            Lime  Shake a tall glass with ice cubes and Angostur...
# 823            Lime  Muddle mint leaves with sugar and lime juice. ...
# 895            Lime  Shake scotch, juice of lime, and powdered suga...
# 1023           Lime  Shake all ingredients (except lime wedge) with...
# 1086           Lime            Mix all ingredients, and pour over ice.
# 1122           Lime  Shake all ingredients (except carbonated water...
# 1141           Lime  Pour all ingredients in mixing glass half fill...
# 1154           Lime  In a highball glass almost filled with ice cub...
# 1181           Lime  Pour the gin and the tonic water into a highba...
# 1203           Lime  Pour Captain Morgan's Spiced Rum over ice, fil...
# 1220           Lime  Shake all ingredients with ice, strain into a ...
# 1293           Lime  Stir all ingredients with ice, strain into a c...
# 1422           Lime  Shake all ingredients (except lime wedge) with...
# 1437           Lime  In an old-fashioned glass almost filled with i...
# 1469           Lime  Shake all ingredients with ice, strain into a ...
# 1515           Lime  Shake all ingredients (except slices of lemon ...
# 1719           Lime  Half-fill a tall glass with ice. Mix the gin a...
#
#        strMeasures     Value MeasureName  Value_numeric  Value_ml  Value_gr  \
# 169              2         2         NaN            NaN       NaN       NaN
# 560              1         1         NaN            NaN       NaN       NaN
# 656              1         1         NaN            NaN       NaN       NaN
# 684        squeeze   squeeze         NaN            NaN       NaN       NaN
# 685   juice of 1/2  juice of         1/2            NaN       NaN       NaN
# 686   juice of 1/2  juice of         1/2            NaN       NaN       NaN
# 689              1         1         NaN            NaN       NaN       NaN
# 806            1/2       1/2         NaN            NaN       NaN       NaN
# 823     juice of 1  juice of           1            NaN       NaN       NaN
# 895   juice of 1/2  juice of         1/2            NaN       NaN       NaN
# 1023    juice of 1  juice of           1            NaN       NaN       NaN
# 1086      2 wedges         2      wedges            NaN       NaN       NaN
# 1122    juice of 1  juice of           1            NaN       NaN       NaN
# 1141  juice of 1/2  juice of         1/2            NaN       NaN       NaN
# 1154             1         1         NaN            NaN       NaN       NaN
# 1181             1         1         NaN            NaN       NaN       NaN
# 1203           NaN       NaN         NaN            NaN       NaN       NaN
# 1220  juice of 1/2  juice of         1/2            NaN       NaN       NaN
# 1293  juice of 1/2  juice of         1/2            NaN       NaN       NaN
# 1422             1         1         NaN            NaN       NaN       NaN
# 1437             1         1         NaN            NaN       NaN       NaN
# 1469  juice of 1/2  juice of         1/2            NaN       NaN       NaN
# 1515  juice of 1/2  juice of         1/2            NaN       NaN       NaN
# 1719       garnish   garnish         NaN            NaN       NaN       NaN
#
#      Garnish_amount Garnish_type MeasureName_copy
# 169             NaN          NaN              NaN
# 560             NaN          NaN              NaN
# 656             NaN          NaN              NaN
# 684             NaN          NaN              NaN
# 685             NaN          NaN              1/2
# 686             NaN          NaN              1/2
# 689             NaN          NaN              NaN
# 806             NaN          NaN              NaN
# 823             NaN          NaN                1
# 895             NaN          NaN              1/2
# 1023            NaN          NaN                1
# 1086            NaN          NaN           wedges
# 1122            NaN          NaN                1
# 1141            NaN          NaN              1/2
# 1154            NaN          NaN              NaN
# 1181            NaN          NaN              NaN
# 1203            NaN          NaN              NaN
# 1220            NaN          NaN              1/2
# 1293            NaN          NaN              1/2
# 1422            NaN          NaN              NaN
# 1437            NaN          NaN              NaN
# 1469            NaN          NaN              1/2
# 1515            NaN          NaN              1/2
# 1719            NaN          NaN              NaN

# %%
cond1 = (df_cons['strIngredients'] == 'Lime') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()
cond2 = (df_cons['Value'] == '1/2')|(df_cons['MeasureName'] == '1/2')
cond3 = (df_cons['Value'] == '1')|(df_cons['MeasureName'] == '1')
cond4 = (df_cons['Value'] == '2')

df_cons['Value_ml'] = np.where(cond1 & cond2, 30/2, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where(cond1 & cond3, 30, df_cons['Value_ml'])
df_cons['Value_ml'] = np.where(cond1 & cond4, 30*2, df_cons['Value_ml'])

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Lime') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()]
# Out:
#            strDrink     strCategory        strGlass strIngredients  \
# 684      Cuba Libra  Ordinary Drink  Highball glass           Lime
# 1203  Happy Skipper  Ordinary Drink  Highball glass           Lime
# 1719     Gin Rickey        Cocktail  Highball glass           Lime
#
#                                         strInstructions strMeasures    Value  \
# 684   Fill tall glass with ice cubes. Add rum. Rub c...     squeeze  squeeze
# 1203  Pour Captain Morgan's Spiced Rum over ice, fil...         NaN      NaN
# 1719  Half-fill a tall glass with ice. Mix the gin a...     garnish  garnish
#
#      MeasureName  Value_numeric  Value_ml  Value_gr Garnish_amount  \
# 684          NaN            NaN       NaN       NaN            NaN
# 1203         NaN            NaN       NaN       NaN            NaN
# 1719         NaN            NaN       NaN       NaN            NaN
#
#      Garnish_type MeasureName_copy
# 684           NaN              NaN
# 1203          NaN              NaN
# 1719          NaN              NaN

# %% [markdown]
# Again, let's check remaining cocktails one by one.

# %%
recipe('Cuba Libra')
# Out:
# Fill tall glass with ice cubes. Add rum. Rub cut edge of lime on rim of glass then squeeze juice into glass. Fill with Coca-Cola. Garnish with lime slice. Enjoy!
#    Ingredient     Measure
# 0    Dark rum   1-2 shot
# 1        Lime    Squeeze
# 2   Coca-Cola  Fill with
# 3         Ice         NaN
# 4         NaN         NaN
# 5         NaN         NaN
# 6         NaN         NaN
# 7         NaN         NaN
# 8         NaN         NaN
# 9         NaN         NaN
# 10        NaN         NaN
# 11        NaN         NaN

# %%
cond1 = (df_cons['strIngredients'] == 'Lime') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()
cond2 = df_cons['strDrink'] == 'Cuba Libra'

df_cons['Value_ml'] = np.where(cond1 & cond2, 30, df_cons['Value_ml'])

# %%
recipe('Happy Skipper')
# Out:
# Pour Captain Morgan's Spiced Rum over ice, fill glass to top with Ginger Ale. Garnish with lime. Tastes like a cream soda. Named for the Gilligan's Island reference ("The Captain" *in* "Ginger" is a Happy Skipper!)
#     Ingredient    Measure
# 0   Spiced rum  1 1/2 cl
# 1   Ginger ale        NaN
# 2         Lime        NaN
# 3          Ice        NaN
# 4          NaN        NaN
# 5          NaN        NaN
# 6          NaN        NaN
# 7          NaN        NaN
# 8          NaN        NaN
# 9          NaN        NaN
# 10         NaN        NaN
# 11         NaN        NaN

# %%
recipe('Gin Rickey')
# Out:
# Half-fill a tall glass with ice. Mix the gin and Grenadine together and pour over the ice. Add the lime or lemon juice and top off with soda water. Decorate the glass with lime and/or lemon slices.
#     Ingredient        Measure
# 0          Gin          2 oz
# 1    Grenadine         1 tsp
# 2        lemon  Juice of 1/2
# 3   Soda Water    Top up with
# 4         Lime        Garnish
# 5          NaN            NaN
# 6          NaN            NaN
# 7          NaN            NaN
# 8          NaN            NaN
# 9          NaN            NaN
# 10         NaN            NaN
# 11         NaN            NaN

# %%
cond1 = (df_cons['strIngredients'] == 'Lime') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()
cond2 = df_cons['strDrink'].isin(['Happy Skipper', 'Gin Rickey'])

df_cons['Garnish_amount'] = np.where(cond1 & cond2, 1, df_cons['Garnish_amount'])
df_cons['Garnish_type'] = np.where(cond1 & cond2, 'slice', df_cons['Garnish_type'])

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Lime') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [strDrink, strCategory, strGlass, strIngredients, strInstructions, strMeasures, Value, MeasureName, Value_numeric, Value_ml, Value_gr, Garnish_amount, Garnish_type, MeasureName_copy]
# Index: []

# %% [markdown]
# ## Oranges.<a class="anchor" id="7"></a>

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Orange') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()]
# Out:
#                         strDrink          strCategory             strGlass  \
# 174     Caribbean Orange Liqueur     Homemade Liqueur        Collins Glass
# 999               Abbey Cocktail       Ordinary Drink       Cocktail glass
# 1472                Bourbon Sour       Ordinary Drink   Whiskey sour glass
# 1528                    Gin Sour       Ordinary Drink   Whiskey sour glass
# 1605                    Rum Sour       Ordinary Drink   Whiskey sour glass
# 1610  Sangria - The World's Best  Punch / Party Drink              Pitcher
# 1643                  Wine Punch  Punch / Party Drink        Collins Glass
# 1700       Classic Old-Fashioned       Ordinary Drink  Old-fashioned glass
# 1712                 French "75"       Ordinary Drink        Collins glass
# 1713                   French 75       Ordinary Drink        Collins glass
# 1804                Apricot Lady       Ordinary Drink  Old-fashioned glass
# 1815              Brandy Cobbler       Ordinary Drink  Old-fashioned glass
# 1831                   Gin Daisy       Ordinary Drink  Old-fashioned glass
# 1839                John Collins       Ordinary Drink        Collins glass
# 1851                 Rum Cobbler       Ordinary Drink  Old-fashioned glass
# 1861                 Tom Collins       Ordinary Drink        Collins glass
#
#      strIngredients                                    strInstructions  \
# 174          Orange  Pare very thinly the bright-colored rind from ...
# 999          Orange  Shake all ingredients (except for the cherry) ...
# 1472         Orange  In a shaker half-filled with ice cubes, combin...
# 1528         Orange  In a shaker half-filled with ice cubes, combin...
# 1605         Orange  In a shaker half-filled with ice cubes, combin...
# 1610         Orange  Mix wine, sugar and fruit, and let sit in the ...
# 1643         Orange  Combine all of the ingredients and pour over a...
# 1700         Orange  In an old-fashioned glass, muddle the bitters ...
# 1712         Orange  In a shaker half-filled with ice cubes, combin...
# 1713         Orange  Combine gin, sugar, and lemon juice in a cockt...
# 1804         Orange  In a shaker half-filled with ice cubes, combin...
# 1815         Orange  In an old-fashioned glass, dissolve the sugar ...
# 1831         Orange  In a shaker half-filled with ice cubes, combin...
# 1839         Orange  Pour all ingredients directly into highball gl...
# 1851         Orange  In an old-fashioned glass, dissolve the sugar ...
# 1861         Orange  In a shaker half-filled with ice cubes, combin...
#
#        strMeasures     Value MeasureName  Value_numeric  Value_ml  Value_gr  \
# 174        3 large         3       large            NaN       NaN       NaN
# 999   juice of 1/4  juice of         1/4            NaN       NaN       NaN
# 1472             1         1         NaN            NaN       NaN       NaN
# 1528             1         1         NaN            NaN       NaN       NaN
# 1605             1         1         NaN            NaN       NaN       NaN
# 1610       1 large         1       large            NaN       NaN       NaN
# 1643             3         3         NaN            NaN       NaN       NaN
# 1700             1         1         NaN            NaN       NaN       NaN
# 1712             1         1         NaN            NaN       NaN       NaN
# 1713             1         1         NaN            NaN       NaN       NaN
# 1804             1         1         NaN            NaN       NaN       NaN
# 1815             1         1         NaN            NaN       NaN       NaN
# 1831             1         1         NaN            NaN       NaN       NaN
# 1839             1         1         NaN            NaN       NaN       NaN
# 1851             1         1         NaN            NaN       NaN       NaN
# 1861             1         1         NaN            NaN       NaN       NaN
#
#      Garnish_amount Garnish_type MeasureName_copy
# 174             NaN          NaN            large
# 999             NaN          NaN              1/4
# 1472            NaN          NaN              NaN
# 1528            NaN          NaN              NaN
# 1605            NaN          NaN              NaN
# 1610            NaN          NaN            large
# 1643            NaN          NaN              NaN
# 1700            NaN          NaN              NaN
# 1712            NaN          NaN              NaN
# 1713            NaN          NaN              NaN
# 1804            NaN          NaN              NaN
# 1815            NaN          NaN              NaN
# 1831            NaN          NaN              NaN
# 1839            NaN          NaN              NaN
# 1851            NaN          NaN              NaN
# 1861            NaN          NaN              NaN

# %%
cond1 = (df_cons['strDrink'] == 'Abbey Cocktail')
cond2 = (df_cons['strIngredients'] == 'Orange')
df_cons['Value_ml'] = np.where(cond1 & cond2, 75/4, df_cons['Value_ml'])

# %%
recipe('John Collins')
# Out:
# Pour all ingredients directly into highball glass filled with ice. Stir gently. Garnish. Add a dash of Angostura bitters.
#            Ingredient           Measure
# 0             Bourbon             2 oz
# 1         Lemon juice             1 oz
# 2               Sugar  1 tsp superfine
# 3           Club soda             3 oz
# 4   Maraschino cherry                1
# 5              Orange                1
# 6                 NaN               NaN
# 7                 NaN               NaN
# 8                 NaN               NaN
# 9                 NaN               NaN
# 10                NaN               NaN
# 11                NaN               NaN

# %%
recipe('Caribbean Orange Liqueur')
# Out:
# Pare very thinly the bright-colored rind from the oranges (no white). Blot the peel on paper towels to remove any excess oil. Put peel in a 4 cup screw-top jar. Add 2 cups vodka. Close jar. Store in a cool, dark place for 2 days or until the vodka has absorbed the flavor. Remove peel and add remaining vodka. Close jar and add remaining cup of vodka. Close the jar and store in a cool dark place at least 1 month to age.
#    Ingredient               Measure
# 0      Orange              3 large
# 1       Vodka               3 cups
# 2       Sugar  1 1/3 cup superfine
# 3         NaN                   NaN
# 4         NaN                   NaN
# 5         NaN                   NaN
# 6         NaN                   NaN
# 7         NaN                   NaN
# 8         NaN                   NaN
# 9         NaN                   NaN
# 10        NaN                   NaN
# 11        NaN                   NaN

# %%
# It's actually not a cocktail and should be dropped together with all other homemage liqueurs.
df_cons.drop(df_cons.loc[df_cons['strCategory']=='Homemade Liqueur'].index, axis=0, inplace=True)

# %%
recipe("Sangria - The World's Best")
# Out:
# Mix wine, sugar and fruit, and let sit in the fridge for 18-24 hours. The mixture will have a somewhat syrupy consistency. Before serving stir in brandy and cut the mixture with soda water until it have a thinner, more wine like consistency. Serve from a pitcher in wine glasses.
#     Ingredient        Measure
# 0     Red wine       1 1/2 L
# 1        Sugar         1 cup
# 2        Lemon       1 large
# 3       Orange       1 large
# 4        Apple       1 large
# 5       Brandy  3-4 oz plain
# 6   Soda water            NaN
# 7          NaN            NaN
# 8          NaN            NaN
# 9          NaN            NaN
# 10         NaN            NaN
# 11         NaN            NaN

# %%
recipe('Wine Punch')
# Out:
# Combine all of the ingredients and pour over a block of ice.
#          Ingredient    Measure
# 0          Red wine  1 bottle
# 1             Lemon         2
# 2      Orange juice     1 cup
# 3            Orange         3
# 4   Pineapple juice     1 cup
# 5               NaN        NaN
# 6               NaN        NaN
# 7               NaN        NaN
# 8               NaN        NaN
# 9               NaN        NaN
# 10              NaN        NaN
# 11              NaN        NaN

# %%
# For Sangria amount of oranges specified stays for juice but for the rest it's for garnish by slices.
cond1 = (df_cons['strDrink'] == "Sangria - The World's Best")
cond2 = (df_cons['strIngredients'] == 'Orange')
df_cons['Value_ml'] = np.where(cond1 & cond2, 75*3, df_cons['Value_ml'])

# %%
# Cocktail 'French "75"' appeares two times.

df_cons.drop(df_cons.loc[df_cons['strDrink']=='French "75"'].index, axis=0, inplace=True)

# %%
# Add orange slice as a garnish for remaining cocktails.

cond1 = (df_cons['strIngredients'] == 'Orange') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()

df_cons['Garnish_amount'] = np.where(cond1, df_cons['Value'], df_cons['Garnish_amount'])
df_cons['Garnish_type'] = np.where(cond1, 'slice', df_cons['Garnish_type'])

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Orange') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [strDrink, strCategory, strGlass, strIngredients, strInstructions, strMeasures, Value, MeasureName, Value_numeric, Value_ml, Value_gr, Garnish_amount, Garnish_type, MeasureName_copy]
# Index: []

# %% [markdown]
# ## Apples.<a class="anchor" id="8"></a>

# %%
df_cons.loc[(df_cons['strIngredients'] == 'Apple') & (df_cons['Value_ml'].isnull()) & df_cons['Garnish_type'].isnull()]
# Out:
#                         strDrink          strCategory strGlass strIngredients  \
# 1767  Sangria - The World's Best  Punch / Party Drink  Pitcher          Apple
#
#                                         strInstructions strMeasures Value  \
# 1767  Mix wine, sugar and fruit, and let sit in the ...     1 large     1
#
#      MeasureName  Value_numeric  Value_ml  Value_gr Garnish_amount  \
# 1767       large            NaN       NaN       NaN            NaN
#
#      Garnish_type MeasureName_copy
# 1767          NaN            large

# %%
cond1 = (df_cons['strDrink'] == "Sangria - The World's Best")
cond2 = (df_cons['strIngredients'] == 'Apple')
df_cons['Value_ml'] = np.where(cond1 & cond2, 100, df_cons['Value_ml'])

# %% [markdown]
# ## Pineapple.<a class="anchor" id="9"></a>

# %%
cond1 = df_cons['strIngredients'] == 'Pineapple'
cond2 = df_cons['MeasureName'].isnull()
df_cons['Value_ml'] = np.where(cond1 & cond2, 900, df_cons['Value_ml'])

# %% [markdown]
# ## Garnishes (remaning from fruit's fix).<a class="anchor" id="10"></a>

# %%
lst = ['strip', 'handful', 'twist', 'whole', 'leaves', 'sprigs', 'sticks']

# %%
df_cons['Value'] = np.where(df_cons['Value'] == '1 long', '1', df_cons['Value'])
df_cons['Value'] = np.where(df_cons['Value'] == '2 fresh', '2', df_cons['Value'])

# %%
df_cons['Garnish_type'] = np.where(df_cons['MeasureName'].isin(lst), df_cons['MeasureName'], df_cons['Garnish_type'])
df_cons['Garnish_amount'] = np.where(df_cons['MeasureName'].isin(lst), df_cons['Value'], df_cons['Garnish_amount'])

# %%
df_cons['Garnish_type'] = np.where(df_cons['strIngredients'] == 'Whipped Cream', 'ml', df_cons['Garnish_type'])
df_cons['Garnish_amount'] = np.where(df_cons['strIngredients'] == 'Whipped Cream', '60', df_cons['Garnish_amount'])

# %%
df_cons['Garnish_type'] = np.where(df_cons['strIngredients'] == 'Cloves', 'whole', df_cons['Garnish_type'])
df_cons['Garnish_amount'] = np.where(df_cons['strIngredients'] == 'Cloves', df_cons['Value'], df_cons['Garnish_amount'])

# %%
lst = ['fill', 'top', 'up', 'with', 'sweet']
df_cons['Garnish_type'] = np.where(df_cons['MeasureName'].isin(lst), 'top up', df_cons['Garnish_type'])
df_cons['Garnish_amount'] = np.where(df_cons['MeasureName'].isin(lst), 0, df_cons['Garnish_amount'])

# %%
df_cons['Garnish_type'] = np.where((df_cons['MeasureName'] == 'pinch')&(df_cons['Value_gr'].isnull()), 'around the rim', df_cons['Garnish_type'])
df_cons['Garnish_type'] = np.where((df_cons['strIngredients'] == 'Salt')&(df_cons['Value_gr'].isnull()), 'rim', df_cons['Garnish_type'])
df_cons['Garnish_amount'] = np.where((df_cons['Garnish_type'] == 'around the rim')&(df_cons['Value_gr'].isnull()), 0.36, df_cons['Garnish_amount'])

# %% [markdown]
# ## Dealing with missing measures.<a class="anchor" id="11"></a>

# %%
cond1 = (df_cons['Value_ml'].isnull())
cond2 = (df_cons['Value_gr'].isnull())
cond3 = (df_cons['Garnish_type'].isnull())
print(len(df_cons.loc[cond1 & cond2 & cond3]['MeasureName']))
print(len(df_cons.loc[cond1 & cond2 & cond3]['MeasureName'].unique()))
df_cons.loc[cond1 & cond2 & cond3]['MeasureName'].unique()
# Out:
# 265
# 2
# array([None, nan], dtype=object)

# %% [markdown]
# # CHECK NONE MEASURES WITH VALUES, PROBABLY ALL CAN BE REPLACED TO 'PART' , I.E. TO 'OZ'

# %%
df_cons.loc[(df_cons['MeasureName'].isnull()) & (~df_cons['Value'].isnull())]
# Out:
#                                   strDrink           strCategory  \
# 0     '57 Chevy with a White License Plate              Cocktail
# 12                              69 Special        Ordinary Drink
# 26                                     ABC                  Shot
# 37                       Absolut limousine         Other/Unknown
# 46                            Adam Sunrise        Ordinary Drink
# ...                                    ...                   ...
# 1862                       Tuxedo Cocktail        Ordinary Drink
# 1872                  Apple Cider Punch #1   Punch / Party Drink
# 1875              Boozy Snickers Milkshake  Milk / Float / Shake
# 1877                      Chocolate Monkey  Milk / Float / Shake
# 1911                            Egg Nog #4   Punch / Party Drink
#
#             strGlass        strIngredients  \
# 0     Highball glass  Creme De Cacao White
# 12     Collins Glass               Gin Dry
# 26        Shot glass              Amaretto
# 37     Collins Glass        Absolut Citron
# 46     Collins Glass                 Vodka
# ...              ...                   ...
# 1862  Cocktail glass                Cherry
# 1872   Collins Glass         Nutmeg Ground
# 1875       Mason jar    Mini-Snickers Bars
# 1877   Parfait glass                Cherry
# 1911      Punch bowl                Nutmeg
#
#                                         strInstructions   strMeasures   Value  \
# 0     1. Fill a rocks glass with ice 2.add white cre...    1 oz white       1
# 12    Pour 2 oz. gin. Add 4 oz. 7-up. Add Lemon Juic...      2 oz dry       2
# 26                             Layered in a shot glass.           1/3     1/3
# 37    Fill Absolut into a glass. Add Lime juice. Add...           2/3     2/3
# 46    Fill blender up with ice. Fill half with Barto...           1/2     1/2
# ...                                                 ...           ...     ...
# 1862  Stir all ingredients with ice and strain into ...             1       1
# 1872  If you use the whole all spice and cloves, tie...  1 tsp ground       1
# 1875  Place the snickers bars in a plastic bag and r...            15      15
# 1877  blend liqeuors with ice-cream, milk and syrup....             1       1
# 1911  In a small mixer bowl beat egg yolks till blen...        ground  ground
#
#      MeasureName  Value_numeric  Value_ml  Value_gr Garnish_amount  \
# 0           None            NaN       NaN       NaN            NaN
# 12          None            NaN       NaN       NaN            NaN
# 26           NaN            NaN       NaN       NaN            NaN
# 37           NaN            NaN       NaN       NaN            NaN
# 46           NaN            NaN       NaN       NaN            NaN
# ...          ...            ...       ...       ...            ...
# 1862         NaN            NaN       NaN       NaN            NaN
# 1872        None            NaN       NaN       NaN            NaN
# 1875         NaN            NaN       NaN       NaN            NaN
# 1877         NaN            NaN       NaN       NaN            NaN
# 1911         NaN            NaN       NaN       NaN            NaN
#
#      Garnish_type MeasureName_copy
# 0             NaN            white
# 12            NaN              dry
# 26            NaN              NaN
# 37            NaN              NaN
# 46            NaN              NaN
# ...           ...              ...
# 1862          NaN              NaN
# 1872          NaN           ground
# 1875          NaN              NaN
# 1877          NaN              NaN
# 1911          NaN              NaN
#
# [193 rows x 14 columns]

# %%
df_cons.loc[(df_cons['MeasureName_copy'] == 'fifth')]
# Out:
#              strDrink          strCategory    strGlass strIngredients  \
# 152        Brain Fart  Punch / Party Drink  Punch bowl      Everclear
# 581     Apricot punch  Punch / Party Drink  Punch bowl      Champagne
# 1056    Apricot punch  Punch / Party Drink  Punch bowl          Vodka
# 1065  Artillery Punch  Punch / Party Drink  Punch bowl       Red Wine
#
#                                         strInstructions strMeasures Value  \
# 152   Mix all ingredients together. Slowly and gentl...     1 fifth   1/5
# 581   Pour all ingrediants into a large punch bowl. ...     4 fifth   4/5
# 1056  Pour all ingrediants into a large punch bowl. ...     1 fifth   1/5
# 1065  Combine all the ingredients in a large punch b...     1 fifth   1/5
#
#      MeasureName  Value_numeric  Value_ml  Value_gr Garnish_amount  \
# 152        fifth            0.2     150.0       NaN            NaN
# 581        fifth            0.8     600.0       NaN            NaN
# 1056       fifth            0.2     150.0       NaN            NaN
# 1065       fifth            0.2     150.0       NaN            NaN
#
#      Garnish_type MeasureName_copy
# 152           NaN            fifth
# 581           NaN            fifth
# 1056          NaN            fifth
# 1065          NaN            fifth

# %%
df_cons.loc[(df_cons['MeasureName'].isnull()) & (~df_cons['Value'].isnull()) & (df_cons['strIngredients'].str.contains('Egg'))]
# Out:
# Empty DataFrame
# Columns: [strDrink, strCategory, strGlass, strIngredients, strInstructions, strMeasures, Value, MeasureName, Value_numeric, Value_ml, Value_gr, Garnish_amount, Garnish_type, MeasureName_copy]
# Index: []

# %%
df_cons.loc[df_cons['strDrink'] == 'Ace']
# Out:
#      strDrink strCategory       strGlass strIngredients  \
# 42        Ace    Cocktail  Martini Glass            Gin
# 530       Ace    Cocktail  Martini Glass      Grenadine
# 1012      Ace    Cocktail  Martini Glass    Heavy Cream
# 1415      Ace    Cocktail  Martini Glass           Milk
# 1657      Ace    Cocktail  Martini Glass      Egg White
#
#                                         strInstructions strMeasures Value  \
# 42    Shake all the ingredients in a cocktail shaker...     2 shots     2
# 530   Shake all the ingredients in a cocktail shaker...    1/2 shot   1/2
# 1012  Shake all the ingredients in a cocktail shaker...    1/2 shot   1/2
# 1415  Shake all the ingredients in a cocktail shaker...    1/2 shot   1/2
# 1657  Shake all the ingredients in a cocktail shaker...   1/2 fresh   1/2
#
#      MeasureName  Value_numeric  Value_ml  Value_gr Garnish_amount  \
# 42         shots            2.0      50.0       NaN            NaN
# 530         shot            0.5      12.5       NaN            NaN
# 1012        shot            0.5      12.5       NaN            NaN
# 1415        shot            0.5      12.5       NaN            NaN
# 1657         egg            0.5      22.5       NaN            NaN
#
#      Garnish_type MeasureName_copy
# 42            NaN            shots
# 530           NaN             shot
# 1012          NaN             shot
# 1415          NaN             shot
# 1657          NaN            fresh

# %%
recipe("Ace")
# Out:
# Shake all the ingredients in a cocktail shaker and ice then strain in a cold glass.
#      Ingredient    Measure
# 0           Gin   2 shots
# 1     Grenadine  1/2 shot
# 2   Heavy cream  1/2 shot
# 3          Milk  1/2 shot
# 4     Egg White  1/2 Fresh
# 5           NaN        NaN
# 6           NaN        NaN
# 7           NaN        NaN
# 8           NaN        NaN
# 9           NaN        NaN
# 10          NaN        NaN
# 11          NaN        NaN

# %%
df_cons.loc[(df_cons['MeasureName'].isnull())
            & (df_cons['Value_ml'].isnull())
            & (df_cons['Value_gr'].isnull())
            & (df_cons['Garnish_amount'].isnull())]['strIngredients'].unique()
# Out:
# array(['Creme De Cacao White', 'Blue Curacao', 'Gin Dry', 'Amaretto',
#        'Absolut Citron', 'Vodka', 'Peppermint Schnapps', 'Tea Hot',
#        'Maui Blue', 'Champagne', 'Vodka Smirnoff', "Bailey'S Irish Cream",
#        'Guinness Stout', 'Sugar Superfine', 'Sambuca White', 'Grenadine',
#        'Corona', 'Coffee', 'Kahlua', 'Cider Hard', '151 Proof Rum Light',
#        'Kool-Aid Grape', 'Carbonated Water', 'Absinthe',
#        'Light Rum Jamaican', 'Sherry Cream', 'Gin', 'Coca-Cola',
#        'Blueberry Schnapps', 'Lime Juice', 'Sweet And Sour',
#        'Sweet Vermouth Red', 'Iced Tea Lemon', 'Grand Marnier',
#        'Chocolate Syrup', 'Root Beer', 'Banana Liqueur', 'Ginger Ale',
#        'Sambuca', 'Peach Schnapps', 'Coffee Cold', 'Kool-Aid Tropical',
#        'Pina Colada Mix', 'Tequila', 'Orange Juice', 'Lemonade Cold',
#        'Milk', 'Tonic Water', 'Schweppes Russchian', 'Triple Sec',
#        'Cognac', 'Water', 'Club Soda', 'Midori Melon Liqueur',
#        'Lemon Peel', 'Lemonade Frozen', 'Soda Water', 'Cream',
#        'Cherry Brandy', 'Lemonade', 'Sugar', 'Wine Muscatel',
#        'Condensed Milk Skimmed', 'Mint', 'Powdered Sugar', 'Coffee Hot',
#        'Water Cold', 'Dry Vermouth', 'Angostura Bitters', 'Olive',
#        'Daiquiri Mix', 'Goldschlager', 'Cream Double',
#        'Dark Rum Jamaican', 'Lemon Juice Sweetened', 'Lemon-Lime Soda',
#        'Fruit Punch Frozen', 'Cranberry Juice', 'Orange Juice Frozen',
#        'Grape Juice Unsweetened', 'Lemon Juice', 'Light Cream',
#        'Sour Mix', 'Maraschino Cherry', 'Strawberries', 'Cherry',
#        'Bitter Lemon', 'Nutmeg', 'Pineapple Juice', 'Orange Peel',
#        'Rum Jamaican', 'Salt', 'Brandy', '151 Proof Rum', 'Milk Skimmed',
#        'Orange Spiral', 'Cinnamon', 'Tonic Water Schweppes', 'Red Wine',
#        'Nutmeg Grated', 'Grapefruit Juice', 'Lime Juice Fresh', '7-Up',
#        'Fruit', 'Coffee Hazlenut', 'Oreo Cookie', 'Cloves', 'Pepper',
#        'Lime Peel', 'Brandy Plain', 'Cherries', 'Nutmeg Ground',
#        'Mini-Snickers Bars', 'Fruit Juice'], dtype=object)

# %%
liquid = ['Blue Curacao', 'Amaretto', 'Absolut Citron', 'Vodka', 'Peppermint Schnapps', 'Champagne', "Bailey'S Irish Cream",
          'Guinness Stout', 'Grenadine', 'Corona', 'Coffee', 'Kahlua', 'Egg Yolk', 'Carbonated Water', 'Absinthe', 'Gin',
          'Coca-Cola', 'Blueberry Schnapps', 'Lime Juice', 'Sweet And Sour', 'Grand Marnier', 'Chocolate Syrup', 'Root Beer',
          'Banana Liqueur',
       'Ginger Ale', 'Sambuca', 'Peach Schnapps', 'Coffee Cold',
       'Pina Colada Mix', 'Tequila', 'Orange Juice', 'Milk',
       'Tonic Water', 'Schweppes Russchian', 'Triple Sec', 'Cognac',
       'Water', 'Egg White', 'Club Soda', 'Midori Melon Liqueur',
       'Lemon Peel', 'Soda Water', 'Cream', 'Cherry Brandy', 'Lemonade',
       'Sugar', 'Mint', 'Powdered Sugar', 'Dry Vermouth',
       'Angostura Bitters', 'Olive', 'Daiquiri Mix', 'Goldschlager',
       'Lemon-Lime Soda', 'Cranberry Juice', 'Lemon Juice', 'Light Cream',
       'Sour Mix', 'Maraschino Cherry', 'Strawberries', 'Cherry',
       'Bitter Lemon', 'Nutmeg', 'Pineapple Juice', 'Orange Peel', 'Salt',
       'Brandy', '151 Proof Rum', 'Orange Spiral', 'Cinnamon', 'Red Wine',
       'Grapefruit Juice', '7-Up', 'Egg White Fresh', 'Fruit',
       'Oreo Cookie', 'Cloves', 'Pepper', 'Lime Peel', 'Cherries',
       'Mini-Snickers Bars', 'Fruit Juice']

# %%
# Check if there are values in both ml and garnish.

# %%
# Drop 'strMeasures', 'Value', 'MeasureName', 'Value_numeric'.

# %%
df_cons.to_csv('./raw_data/stage3.csv')

# %%
# df_cons = pd.read_csv('./raw_data/stage3.csv')
# df_cons.drop('Unnamed: 0', axis=1, inplace=True)
